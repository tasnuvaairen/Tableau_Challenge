# %%
#pip install citipy

# %% [markdown]
# ## Dependencies

# %%
import pandas as pd
from sqlalchemy import create_engine
import datetime as dt
import json
import requests
import time
import urllib
#from api_keys import weather_api_key
#from citipy import citipy
import matplotlib.pyplot as plt

# %% [markdown]
# ### Store CSV into DataFrame

# %%
# Import citibike CSV file and Read it (Jan-Jun, 2019)


citibike1901_csv = pd.read_csv('201901-citibike-tripdata.csv')
citibike1902_csv = pd.read_csv('201902-citibike-tripdata.csv')
citibike1903_csv = pd.read_csv('201903-citibike-tripdata.csv')
citibike1904_csv = pd.read_csv('201904-citibike-tripdata.csv')
citibike1905_csv = pd.read_csv('201905-citibike-tripdata.csv')
citibike1906_csv = pd.read_csv('201906-citibike-tripdata.csv')
citibike1907_csv = pd.read_csv('201907-citibike-tripdata.csv')
citibike1908_csv = pd.read_csv('201908-citibike-tripdata.csv')
citibike1909_csv = pd.read_csv('201909-citibike-tripdata.csv')
citibike1910_csv = pd.read_csv('201910-citibike-tripdata.csv')
citibike1911_csv = pd.read_csv('201911-citibike-tripdata.csv')
citibike1912_csv = pd.read_csv('201912-citibike-tripdata.csv')

combined_df = pd.concat([citibike1901_csv, citibike1902_csv, citibike1903_csv,citibike1904_csv, citibike1905_csv, 
                         citibike1906_csv, citibike1907_csv, citibike1908_csv, citibike1909_csv, citibike1910_csv, 
                         citibike1911_csv, citibike1912_csv])

combined_df
# Out:
#     tripduration         starttime          stoptime  start station id  \
# 0            320   1/1/19 12:01 AM   1/1/19 12:07 AM              3160
# 1            316   1/1/19 12:04 AM   1/1/19 12:10 AM               519
# 2            591   1/1/19 12:06 AM   1/1/19 12:15 AM              3171
# 3           2719   1/1/19 12:07 AM   1/1/19 12:52 AM               504
# 4            303   1/1/19 12:07 AM   1/1/19 12:12 AM               229
# ..           ...               ...               ...               ...
# 94           844  12/1/19 12:13 AM  12/1/19 12:27 AM               453
# 95           147  12/1/19 12:13 AM  12/1/19 12:15 AM              3373
# 96           467  12/1/19 12:13 AM  12/1/19 12:21 AM               402
# 97          1995  12/1/19 12:13 AM  12/1/19 12:47 AM               533
# 98           605  12/1/19 12:13 AM  12/1/19 12:24 AM              3175
#
#              start station name  start station latitude  \
# 0   Central Park West & W 76 St               40.778968
# ...

# %% [markdown]
# ## Clean CSV data

# %%
# Clean the CSV DF Column headers
citibike_2019 = combined_df.rename(columns = {'tripduration':'Trip Duration', 'starttime':'Start Time', 
                                                'stoptime':'Stop Time','start station id':'Start Station ID',
                                                'start station name':'Start Station Name', 'start station latitude':'Start Station Latitude', 
                                                'start station longitude':'Start Station Longitude','end station id':'End Station ID',
                                                'end station name':'End Station Name','end station latitude':'End Station Latitude', 
                                                'end station longitude':'End Station Longitude','bikeid':'Bike ID','usertype':'User Type',
                                                'birth year':'Birth Year', 'gender': 'Gender'})
citibike_2019
# Out:
#     Trip Duration        Start Time         Stop Time  Start Station ID  \
# 0             320   1/1/19 12:01 AM   1/1/19 12:07 AM              3160
# 1             316   1/1/19 12:04 AM   1/1/19 12:10 AM               519
# 2             591   1/1/19 12:06 AM   1/1/19 12:15 AM              3171
# 3            2719   1/1/19 12:07 AM   1/1/19 12:52 AM               504
# 4             303   1/1/19 12:07 AM   1/1/19 12:12 AM               229
# ..            ...               ...               ...               ...
# 94            844  12/1/19 12:13 AM  12/1/19 12:27 AM               453
# 95            147  12/1/19 12:13 AM  12/1/19 12:15 AM              3373
# 96            467  12/1/19 12:13 AM  12/1/19 12:21 AM               402
# 97           1995  12/1/19 12:13 AM  12/1/19 12:47 AM               533
# 98            605  12/1/19 12:13 AM  12/1/19 12:24 AM              3175
#
#              Start Station Name  Start Station Latitude  \
# ...

# %%
# Fix the date and time columns
citibike_2019['Start Date']=pd.to_datetime(citibike_2019['Start Time']).dt.strftime('%Y-%m-%d') #.date
citibike_2019['Start Time']=pd.to_datetime(citibike_2019['Start Time']).dt.strftime('%H:%M') #.dt.time
citibike_2019['Stop Date']=pd.to_datetime(citibike_2019['Stop Time']).dt.strftime('%Y-%m-%d') #.date
citibike_2019['Stop Time']=pd.to_datetime(citibike_2019['Stop Time']).dt.strftime('%H:%M') #.dt.time
citibike_2019
# Out:
#     Trip Duration Start Time Stop Time  Start Station ID  \
# 0             320      00:01     00:07              3160
# 1             316      00:04     00:10               519
# 2             591      00:06     00:15              3171
# 3            2719      00:07     00:52               504
# 4             303      00:07     00:12               229
# ..            ...        ...       ...               ...
# 94            844      00:13     00:27               453
# 95            147      00:13     00:15              3373
# 96            467      00:13     00:21               402
# 97           1995      00:13     00:47               533
# 98            605      00:13     00:24              3175
#
#              Start Station Name  Start Station Latitude  \
# 0   Central Park West & W 76 St               40.778968
# 1         Pershing Square North               40.751873
# 2       Amsterdam Ave & W 82 St               40.785247
# ...

# %% [markdown]
# ### Connect to local database

# %%
#rds_connection_string = "<postgres>:<postgres>@localhost:5432/citibike_db"
#engine = create_engine(f'postgresql://{rds_connection_string}')
#engine = create_engine('postgresql://postgres:s1111111@localhost:5432/citibike_db')
engine = create_engine('postgresql://postgres:postgres@localhost:5432/Tablueau_citibike')
connection = engine.connect()

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# ['citibike_2019_1']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %% [markdown]
# ### Confirm data has been added by querying the customer_name table
# * NOTE: can also check using pgAdmin

# %%
col_combined_df.to_sql(name='citibike_2019_1', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# UndefinedColumn: column "Trip Duration" of relation "citibike_2019_1" does not exist
# LINE 1: INSERT INTO citibike_2019_1 ("Trip Duration", "Start Time", ...
#                                      ^
#
#
# ...

# %%
pd.read_sql_query('select * from citibike_2019_1', con=engine).head()
# Out:
# Empty DataFrame
# Columns: [tripduration, starttime, stoptime, start_station_id, start_station_name, start_station_latitude, start_station_longitude, end_station_id, end_station_name, end_station_latitude, end_station_longitude, bike_id, user_type, birth_year, gender]
# Index: []
